# %%
nums = [1, 2, 3, 4, 5, 6]
#透過索引取值
print(nums[0])
print(nums[5])

#透過slice取值
print(nums[0:3])
print(nums[:3])
print(nums[-3:-1])
print(nums[-3:])
# Out:
# 1
# 6
# [1, 2, 3]
# [1, 2, 3]
# [4, 5]
# [4, 5, 6]

# %%
nums = [1, 2, 3, 4, 5, 6]
#透過索引取值
print(nums[0])
print(nums[5])

#透過slice取值
print(nums[0:3])
print(nums[:3])
print(nums[-3:-1])
print(nums[-3:])

for num in nums:
    print(num)
# Out:
# 1
# 6
# [1, 2, 3]
# [1, 2, 3]
# [4, 5]
# [4, 5, 6]
# 1
# 2
# 3
# 4
# 5
# 6

# %%
print(type(nums))
# Out:
# <class 'list'>

# %%
nums = [1, 2, 3, 4, 5, 6]
nums.append(7)
print (nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
nums = [1, 2, 3, 4, 5, 6]
nums.insert(0,-1)
print(nums)
# Out:
# [-1, 1, 2, 3, 4, 5, 6]

# %%
nums = [1, 2, 3, 4, 5, 6]
nums.clear()
nums
# Out:
# []
